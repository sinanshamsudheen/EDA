# %% [markdown]
# <a href="https://colab.research.google.com/github/sinanshamsudheen/EDA/blob/main/bing-image-downloader.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install bing-image-downloader

# %%
from bing_image_downloader import downloader

# %%
downloader.download('kylian mbappe face',limit=200,output_dir="/content/drive/MyDrive/sample_ds/")
# Out:
# Streaming output truncated to the last 5000 lines.
# [%] Indexed 20 Images on Page 8381.
#
# ...
#
#
#
# [!!]Indexing page: 8382
#
# [%] Indexed 20 Images on Page 8382.
#
# ...
#
#
#
# [!!]Indexing page: 8383
#
# [%] Indexed 20 Images on Page 8383.
#
# ...
#
#
#
# [!!]Indexing page: 8384
#
# [%] Indexed 20 Images on Page 8384.
#
# ...
#
#
#
# [!!]Indexing page: 8385
#
# [%] Indexed 20 Images on Page 8385.
#
# ...
#
#
#
# [!!]Indexing page: 8386
#
# [%] Indexed 20 Images on Page 8386.
#
# ...
#
#
#
# [!!]Indexing page: 8387
#
# [%] Indexed 20 Images on Page 8387.
#
# ...
#
#
#
# [!!]Indexing page: 8388
#
# [%] Indexed 20 Images on Page 8388.
#
# ...
#
#
#
# [!!]Indexing page: 8389
#
# [%] Indexed 20 Images on Page 8389.
#
# ...
#
#
#
# [!!]Indexing page: 8390
#
# [%] Indexed 20 Images on Page 8390.
#
# ...
#
#
#
# [!!]Indexing page: 8391
#
# [%] Indexed 20 Images on Page 8391.
#
# ...
#
#
#
# [!!]Indexing page: 8392
#
# [%] Indexed 20 Images on Page 8392.
#
# ...
#
#
#
# [!!]Indexing page: 8393
#
# [%] Indexed 20 Images on Page 8393.
#
# ...
#
#
#
# ...

# %%
downloader.download('neymar jr face',limit=200,output_dir="/content/drive/MyDrive/sample_ds/")
